# %%
1+3
# Out:
# 4

# %%
print('anil')
# Out:
# anil

# %%
a=10

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
a= anil wasare
# Out:
#   File "<ipython-input-6-c734f42b6141>", line 1
#     a= anil wasare
#                  ^
# SyntaxError: invalid syntax

# %%
type(a)
# Out:
# int

# %%
a="anil wasare"

# %%
type(a)
# Out:
# str

# %%
d=5+6j

# %%
d
# Out:
# (5+6j)

# %%
type(d)
# Out:
# complex

# %%
a='ADHdhasddfffhfhfffffdsfdfs'

# %%
a
# Out:
# 'ADHdhasddfffhfhfffffdsfdfs'

# %%
A=True

# %%
type(A)
# Out:
# bool

# %%
a,b,c,d,e=120,'abnil',4+6j,12.03, True

# %%
a
# Out:
# 120

# %%
b
# Out:
# 'abnil'

# %%
c
# Out:
# (4+6j)

# %%
d
# Out:
# 12.03

# %%
e
# Out:
# True

# %%
c
# Out:
# (4+6j)

# %%
c+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-baf87dc38fa6> in <module>
# ----> 1 c+b
#
# TypeError: unsupported operand type(s) for +: 'complex' and 'str'

# %%
c+d
# Out:
# (16.03+6j)

# %%
True+True
# Out:
# 2

# %%
True+False
# Out:
# 1

# %%
False+False
# Out:
# 0

# %%
1+True
# Out:
# 2

# %%
0+1
# Out:
# 1

# %%
False+2
# Out:
# 2

# %%
False-True
# Out:
# -1

# %%
print
# Out:
# <function print>

# %%
a=input('aakaaaa')
# Out:
# aakaaaaaaaa
# 'aaaa'

# %%
b=45

# %%
a
# Out:
# 120

# %%
b
# Out:
# 45

# %%
a+b
# Out:
# 165

# %%
a=input('anil')
# Out:
# anil33566

# %%
a
# Out:
# '33566'

# %%
int(a)+b
# Out:
# 33611

# %%
a
# Out:
# '33566'

# %%
pwd()
# Out:
# '/home/jovyan/binder'
